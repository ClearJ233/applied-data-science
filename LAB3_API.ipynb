# %% [markdown]
# ## API lab
#
# ### Introduction:
#
# While many data sets are provided though downloadable files, some are provided through application programming interface (API) which allows the code to access some data without downloading the entire dataset.
#
# APIs provide sets of functions and procedures that allow accessing the features or data from an application or other service.
#
#
# #### REST API
# REST is essentially a set of useful conventions for structuring a web API. 'Web API' means an API that you interact with over HTTP, making requests to specific URLs, and often getting relevant data back in the response.
#
# ### Uses
# - Scraping real time information - useful for example for accessing travel route info from mapping applications, social media feed. And any other data that being updated in real time or is changing quickly. Another example of this is stock price data. It doesn’t really make sense to regenerate a data set and download it every minute
# - Getting only the desired tables through filtering instead of downloading the entire data sets. Reddit comments are one example. It doesn’t make much sense (plus won't be permitted) to download the entire Reddit database if we want only some information
#
# ### General Terminology
#
# #### Types of requests
# characterize what action we are going to take by referring to the API
#
# - GET: retrieve information (like search results). This is the most common type of request. Using it, we can get the data we are interested in from those that the API is ready to share.
# - POST: adds new data to the server. Using this type of request, you can, for example, add a new item to your inventory.
# - PUT: changes existing information. For example, using this type of request, it would be possible to change the color or value of an existing product.
# - DELETE: deletes existing information
#
# #### Status codes
# briefly describe the result of the call.
#
# - 200 – OK. The request was successful. The answer itself depends on the method used (GET, POST, etc.) and the API specification.
# - 204 – No Content. The server successfully processed the request and did not return any content.
# - 301 – Moved Permanently. The server responds that the requested page (endpoint) has been moved to another address and redirects to this address.
# - 400 – Bad Request. The server cannot process the request because the client-side errors (incorrect request format).
# - 401 – Unauthorized. Occurs when authentication was failed, due to incorrect credentials or even their absence.
# - 403 – Forbidden. Access to the specified resource is denied.
# - 404 – Not Found. The requested resource was not found on the server.
# - 500 – Internal Server Error. Occurs when an unknown error has occurred on the server.
#
# #### Endpoints
# Usually, an Endpoint is a specific address (for example, https://weather-in-london.com/forecast), by referring to which you get access to certain features/data (in this example above – the weather forecast for London). Commonly, the name (address) of the endpoint corresponds to the functionality it provides.

# %% [markdown]
# ### HereMap API
# Provides mapping, location data and routing information services worldwide. Routing info is available for transit, walking, driving, bike modes.

# %%
import pandas as pd
import glob #Unix style pathname pattern expansion
import numpy as np
from dateutil import parser #powerful extensions to datetime; offers a generic date/time string parser
import time
from tqdm import tqdm #Customisable progressbar for iterators
try: #spelling depends on enviroment version 
    import urllib2 as urllib #URL handling module
except ImportError:
    import urllib.request as urllib
import json
import geopandas as gpd
import sys
from IPython.display import clear_output #Clears the output of the current cell receiving output
import requests #the module for making HTTP requests in Python; provides GET funcionality

# %% [markdown]
# #### Request API key by creating free account
#
# https://developer.here.com/sign-up?create=Freemium-Basic&keepState=true&step=account
#
# (We recommend not to put your credit card info, all the API services will work for free without having to put your card)
#
# 1. After signing in, click on 'Start with REST APIs' part. Follow the instructions in the 'Access Manager' to create the app.
# 2. After setting up the app, create the API key in the 'Credentials' section.
#
# Note: For some API services, you may need an additional step to create a 'Project'. Please follow the below instructions to create a project and link your app to it. (not needed for this notebook/assignment)
#
# 1. Open the Projects Manager from the launcher.
# 2. Click Create new project and name the project.
# 3. In the 'Services' section, search for the services you'd like to access with the API. (eg. Maps services)
# 4. Link your app from the "Access Manager" tab to the above project and start using the API services.

# %% [markdown]
# #### Example 1: getting driving time

# %% [markdown]
# #### API endpoint
# https://developer.here.com/documentation/routing-api/8.3.1/dev_guide/topics/send-request.html

# %% [markdown]
# #### Sample request
#
# An API request needs an endpoint link with API key to fetch data. In some cases, you may also need appID and appCode to make a request. When you make a account in a particular API service, you will be asked to create and name your app. When you finish this step, you will be provided with a unique API key together with appID and appCode as a unique identifier for your app.
#
# Please not that various APIs have certain restrictions on their usage. Please make sure to read the the usage terms before making acccount (especially if you are asked to enter your payment info beforehand!)
#
# HereMap API has 250k free requests per month. (And it does not ask for credit card info when you create an account)
#
# Also, please note the below example uses an API key for this lab's demonstration purposes only. Please create your HereMap account and get your unique API key when attempting the lab or homeworks yourself.
#
# retreive a driving route between the two given points

# %%
# enter your api key from HereMap
apiKey = ''

lon_pickup, lat_pickup = -73.972136, 40.744301 ##origin: A point in Manhattan (around E 35th street)
lon_dropoff, lat_dropoff = -74.172945, 40.680108 # destination: Newark airport

# %% [markdown]
# #### Routing API info and documentation
# https://developer.here.com/documentation/routing-api/dev_guide/topics/use-cases/calculate-route.html
#
# Note the driving API endpoint is 'https://router.hereapi.com/v8/routes?transportMode=car&origin={},{}&destination={},{}&return=summary&apikey={}', which essentially gives the driving directions from origin to destination together with a summary of the whole trip.
#
# For the above origin-destination lat-longs, the endpoint will look like
#
# 'https://router.hereapi.com/v8/routes?transportMode=car&origin=40.744301,-73.972136&destination=40.680108,-74.172945&return=summary&apikey={}'
#
# Basically, the origin lat-long go in after the 'waypoint0=geo!' field and destination lat-long go in after 'waypoint1=geo!' field. Instead of manually putting these lat-long in the code, the pythonic way to do this is by the 'format' function. Wherever we need to insert variables, we put '{}' in the url and then specify the variables in their respective order of appearing in the url in the 'format' command.

# %%
url = str('https://router.hereapi.com/v8/routes?transportMode=car&origin={},{}&destination={},{}&return=summary&apikey={}'.format(
    lat_pickup, lon_pickup, lat_dropoff, lon_dropoff, apiKey))
print(url)
# Out:
# https://router.hereapi.com/v8/routes?transportMode=car&origin=40.744301,-73.972136&destination=40.680108,-74.172945&return=summary&apikey=

# %% [markdown]
# Now we'll make a request with the below command

# %%
data = urllib.urlopen(url).read().decode('utf-8')
data = json.loads(data)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 data = urllib.urlopen(url).read().decode('utf-8')
#       2 data = json.loads(data)
#
# File ~\anaconda3\lib\urllib\request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File ~\anaconda3\lib\urllib\request.py:523, in OpenerDirector.open(self, fullurl, data, timeout)
#     521 for processor in self.process_response.get(protocol, []):
#     522     meth = getattr(processor, meth_name)
# --> 523     response = meth(req, response)
#     525 return response
#
# File ~\anaconda3\lib\urllib\request.py:632, in HTTPErrorProcessor.http_response(self, request, response)
#     629 # According to RFC 2616, "2xx" code indicates that the client's
#     630 # request was successfully received, understood, and accepted.
#     631 if not (200 <= code < 300):
# --> 632     response = self.parent.error(
#     633         'http', request, response, code, msg, hdrs)
#     635 return response
#
# File ~\anaconda3\lib\urllib\request.py:561, in OpenerDirector.error(self, proto, *args)
#     559 if http_err:
#     560     args = (dict, 'default', 'http_error_default') + orig_args
# --> 561     return self._call_chain(*args)
#
# File ~\anaconda3\lib\urllib\request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File ~\anaconda3\lib\urllib\request.py:641, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     640 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 641     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 401: Unauthorized

# %% [markdown]
# The fetched data gives driving directions together with a summary of the whole trip

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 data
#
# NameError: name 'data' is not defined

# %% [markdown]
# The retrived output contains all information in the 'routes' key, including the travel time ('duration') and travel distance ('length')

# %% [markdown]
# Let's print the time and distance of the whole trip

# %%
# get travel time in seconds
data['routes'][0]['sections'][0]['summary']['duration']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 2>()
#       1 # get travel time in seconds
# ----> 2 data['routes'][0]['sections'][0]['summary']['duration']
#
# NameError: name 'data' is not defined

# %%
# travel distance in meters
data['routes'][0]['sections'][0]['summary']['length']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 2>()
#       1 # travel distance in meters
# ----> 2 data['routes'][0]['sections'][0]['summary']['length']
#
# NameError: name 'data' is not defined

# %% [markdown]
# #### Example 2: getting transit time

# %% [markdown]
# #### API info and documentation
# https://developer.here.com/documentation/public-transit/dev_guide/quick-start.html

# %%
lon_pickup, lat_pickup = -73.972136, 40.744301
lon_dropoff, lat_dropoff = -74.008704, 40.708592

# API endpoint link
url = str('https://transit.router.hereapi.com/v8/routes?apiKey={}&origin={},{}&destination={},{}'.format(apiKey, lat_pickup, lon_pickup, 
                                                                                                        lat_dropoff, lon_dropoff))

data = urllib.urlopen(url).read().decode('utf-8')
data = json.loads(data)
data
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 8>()
#       4 # API endpoint link
#       5 url = str('https://transit.router.hereapi.com/v8/routes?apiKey={}&origin={},{}&destination={},{}'.format(apiKey, lat_pickup, lon_pickup,
#       6                                                                                                         lat_dropoff, lon_dropoff))
# ----> 8 data = urllib.urlopen(url).read().decode('utf-8')
#       9 data = json.loads(data)
#      10 data
#
# File ~\anaconda3\lib\urllib\request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File ~\anaconda3\lib\urllib\request.py:523, in OpenerDirector.open(self, fullurl, data, timeout)
#     521 for processor in self.process_response.get(protocol, []):
#     522     meth = getattr(processor, meth_name)
# --> 523     response = meth(req, response)
#     525 return response
#
# File ~\anaconda3\lib\urllib\request.py:632, in HTTPErrorProcessor.http_response(self, request, response)
#     629 # According to RFC 2616, "2xx" code indicates that the client's
#     630 # request was successfully received, understood, and accepted.
#     631 if not (200 <= code < 300):
# --> 632     response = self.parent.error(
#     633         'http', request, response, code, msg, hdrs)
#     635 return response
#
# File ~\anaconda3\lib\urllib\request.py:561, in OpenerDirector.error(self, proto, *args)
#     559 if http_err:
#     560     args = (dict, 'default', 'http_error_default') + orig_args
# --> 561     return self._call_chain(*args)
#
# File ~\anaconda3\lib\urllib\request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File ~\anaconda3\lib\urllib\request.py:641, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     640 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 641     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 401: Unauthorized

# %% [markdown]
# Note that retrieved output keys are different from what we obtained in case of driving direction request.
#
# Here all data is present in the 'routes' key with information regarding intermediate stations. If we are interested in overall travel time, we'll need to access the first and last 'routes' and get the difference between the last arrival time and first departure time.
#
# Important: You may get the retrieved repsonse other than above if any transit route is not available from specified origin to destination.
# Invalid responses are 'Timestamp out of validity period' and 'No result found'

# %%
# get travel time - subtract arrival time from last route and departure time from first route

(parser.isoparse(data['routes'][0]['sections'][-1]['arrival']['time']) 
    - parser.isoparse(data['routes'][0]['sections'][0]['departure']['time']))
# Out:
# datetime.timedelta(seconds=2040)

# %%
# convert to minutes

str(parser.isoparse(data['routes'][0]['sections'][-1]['arrival']['time']) 
    - parser.isoparse(data['routes'][0]['sections'][0]['departure']['time']))
# Out:
# '0:34:00'

# %% [markdown]
# Travel time

# %% [markdown]
# ## Now access information for a sample of selected origin-destination points

# %%
# sample points lat-longs

df = pd.read_csv('https://raw.githubusercontent.com/CUSP2020PUI/Data/master/samplePoints.csv')
df.head()
# Out:
#    LocationID  lon_pickup  lat_pickup  LocationID2  lon_dropoff  lat_dropoff
# 0           1  -74.174000   40.691831          145   -73.948891    40.745379
# 1           2  -73.831299   40.616745          203   -73.739473    40.657853
# 2           3  -73.847422   40.864474           77   -73.895364    40.666559
# 3           4  -73.976968   40.723752          158   -74.008984    40.735035
# 4           5  -74.188484   40.552659          123   -73.964334    40.599954

# %%
len(df) ##one random point per each zip code
# Out:
# 263

# %% [markdown]
# Function for getting driving time for a dataframe of above type

# %%
def driving(file, apiKey): 
    '''
    Input: the file that contain origin-destination lan/long information; keys from Map
    Output: list of driving times corresponding the input O-D pairs
    '''
    duration_list= []  # list for storing times
    for index, row in tqdm(file.iterrows()): # iterating through all rows of sample points
        lon_pickup = row['lon_pickup']  
        lat_pickup = row['lat_pickup']
        lon_dropoff = row['lon_dropoff']
        lat_dropoff = row['lat_dropoff']
        
        # specifying origin-desination lat-longs in the endpoint and making request
        url = str('https://router.hereapi.com/v8/routes?transportMode=car&origin={},{}&destination={},{}&return=summary&apikey={}'.format(lat_pickup, lon_pickup, lat_dropoff, lon_dropoff, apiKey))
        data = urllib.urlopen(url).read().decode('utf-8')
        data = json.loads(data)
        
        # append travel time to 'duration' list, nan if no travel time retrieved
        try:    
            duration = data['routes'][0]['sections'][0]['summary']['duration']
        except:
            duration = np.nan
            
        duration_list.append(duration)

    return duration_list

# %% [markdown]
# Passing 10 random O-D pairs

# %%
sample = df.sample(10, random_state=2020)
sample.reset_index(drop=True, inplace=True)

sample
# Out:
#    LocationID  lon_pickup  lat_pickup  LocationID2  lon_dropoff  lat_dropoff
# 0         110  -74.128342   40.545780          254   -73.858948    40.882157
# 1          51  -73.828264   40.873973           92   -73.828859    40.761102
# 2         166  -73.961764   40.809457          234   -73.990458    40.740337
# 3         207  -73.899353   40.763986          248   -73.872289    40.834165
# 4         195  -74.009178   40.675549           68   -73.999917    40.748428
# 5         251  -74.125348   40.616880          114   -73.997380    40.728340
# 6          71  -73.937966   40.644288          118   -74.132979    40.586555
# 7         139  -73.744234   40.677098          202   -73.949952    40.761900
# 8          76  -73.876821   40.660935          240   -73.881978    40.894599
# 9         165  -73.956825   40.620924          258   -73.855767    40.688721

# %% [markdown]
# Calling the function to get responses from API

# %%
sample['driving_time'] = driving(sample, apiKey)
sample
# Out:
# 10it [00:01,  8.88it/s]
#    LocationID  lon_pickup  lat_pickup  LocationID2  lon_dropoff  lat_dropoff  \
# 0         110  -74.128342   40.545780          254   -73.858948    40.882157
# 1          51  -73.828264   40.873973           92   -73.828859    40.761102
# 2         166  -73.961764   40.809457          234   -73.990458    40.740337
# 3         207  -73.899353   40.763986          248   -73.872289    40.834165
# 4         195  -74.009178   40.675549           68   -73.999917    40.748428
# 5         251  -74.125348   40.616880          114   -73.997380    40.728340
# 6          71  -73.937966   40.644288          118   -74.132979    40.586555
# 7         139  -73.744234   40.677098          202   -73.949952    40.761900
# 8          76  -73.876821   40.660935          240   -73.881978    40.894599
# 9         165  -73.956825   40.620924          258   -73.855767    40.688721
#
#    driving_time
# 0          3877
# 1          1252
# 2          1102
# 3          1139
# 4          1040
# 5          1824
# 6          1940
# 7          2066
# 8          2350
# 9          1724

# %% [markdown]
# ### NYC Open data API:
# NYC open data offers API for almost every available data from crime, housing, 311, taxi etc.
# Also its free for the most part and no account needed
#
# https://opendata.cityofnewyork.us/

# %% [markdown]
# #### Example: Endpoint for 2018 taxi data
# https://data.cityofnewyork.us/resource/t29m-gskq.json

# %%
# some parameters to filter the data. We can specify as many parameters as columns in the table.
# reference: https://dev.socrata.com/foundry/data.cityofnewyork.us/t29m-gskq

# extracting info for a specific O-D pair corresponding to near E 35th st as pick up and Newark airport as drop off
# this is around the same pick-up and drop-off location we used to get driving time from HereMap API
parameter = {'pulocationid':162, 'dolocationid':1}

# %% [markdown]
# making API request
#
# 'requests' is another package of making web requests. Highly uselful in the case of REST APIs and we can provide parameters together in one line of code. We'll use the 'get' method to retrieve data

# %%
url =  "https://data.cityofnewyork.us/resource/t29m-gskq.json"
r = requests.get(url = url, params=parameter)
data = r.json()

# %% [markdown]
# fisrt three returned observations

# %%
data[:3]
# Out:
# [{'vendorid': '1',
#   'tpep_pickup_datetime': '2018-02-14T13:10:19.000',
#   'tpep_dropoff_datetime': '2018-02-14T13:53:15.000',
#   'passenger_count': '1',
#   'trip_distance': '17.40',
#   'ratecodeid': '3',
#   'store_and_fwd_flag': 'N',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'payment_type': '1',
#   'fare_amount': '68.5',
#   'extra': '0',
#   'mta_tax': '0',
#   'tip_amount': '12',
#   'tolls_amount': '10.5',
#   'improvement_surcharge': '0.3',
#   'total_amount': '91.3'},
#  {'vendorid': '2',
#   'tpep_pickup_datetime': '2018-02-14T14:25:43.000',
#   'tpep_dropoff_datetime': '2018-02-14T15:05:18.000',
#   'passenger_count': '2',
#   'trip_distance': '17.40',
#   'ratecodeid': '3',
#   'store_and_fwd_flag': 'N',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'payment_type': '1',
#   'fare_amount': '68',
#   'extra': '0',
#   'mta_tax': '0',
#   'tip_amount': '0',
#   'tolls_amount': '16.1',
#   'improvement_surcharge': '0.3',
#   'total_amount': '84.4'},
#  {'vendorid': '1',
#   'tpep_pickup_datetime': '2018-02-14T14:38:48.000',
#   'tpep_dropoff_datetime': '2018-02-14T15:36:03.000',
#   'passenger_count': '1',
#   'trip_distance': '21.70',
#   'ratecodeid': '3',
#   'store_and_fwd_flag': 'N',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'payment_type': '2',
#   'fare_amount': '81',
#   'extra': '0',
#   'mta_tax': '0',
#   'tip_amount': '0',
#   'tolls_amount': '15.49',
#   'improvement_surcharge': '0.3',
#   'total_amount': '96.79'}]

# %% [markdown]
# Note that the returned request contains information reagrding pick up and drop off times, distance covered, fare amount, number of passengers etc. Essentially, it returns all info provided by TLC in any csv file.

# %% [markdown]
# Let's get travel time from first observation

# %%
# travel time in seconds
parser.parse(data[0]['tpep_dropoff_datetime']) - parser.parse(data[0]['tpep_pickup_datetime'])
# Out:
# datetime.timedelta(seconds=2576)

# %% [markdown]
# Note the travel time returned is around 40 minutes compared to around 28 minutes from driving time retrieved from HereMap API before. Also note time can vary based on the pick up times, the above time of 40 min correspond to pick up around 7pm.

# %% [markdown]
# #### get yellow taxi times for O-D pairs as before
#
# #### Note: taxi data can be full of absurd values in terms of travel times/fares/distances. So we need to filter out all noise while we extract.
# #### We'll make the same checks for filtering as we did in the taxi data lab
#
# 1. Get rid of observations with travel time > 1 min and < 100 min
# 2. Speed (distance/time) should be > 2mph and <80mph
# 3. Fare should be < 300 USD and > 2.5 USD
# 4. distance traveled < 100 and > 0.3

# %%
def taxiTime(df):
    
    times = [] # list for storing travel times
    
    for index, row in df.iterrows(): # iterating through all rows of sample points
        
        # specify parameters for making request
        parameters = {'pulocationid':int(row['LocationID']), 'dolocationid':int(row['LocationID2'])}
        
        url =  "https://data.cityofnewyork.us/resource/t29m-gskq.json"
        r = requests.get(url = url, params=parameters)
        data = r.json()
        
        travelTime = []
        
        for obs in data: # iterating through each returned observation for the returned data 
            
            # making sanity checks and appending times to 'traveTime' list
            try:
                time = parser.parse(obs['tpep_dropoff_datetime']) - parser.parse(obs['tpep_pickup_datetime'])
                time = time.total_seconds()
                fare = float(obs['fare_amount'])
                distance = float(obs['trip_distance'])
                speed = distance/(time/3600)

                if (time < 6000 and time > 60 and fare < 200  
                    and fare > 2.5 and fare < 300 and speed < 80  and speed > 2 and distance > 0.3 and 
                    distance < 100):
                    travelTime.append(time)
                    
            except: 
                pass
            
        # now appending the mean of travel times retrieved above to the 'times' list
    
        times.append(np.mean(travelTime))
        
        
    return times

# %%
sample['TLC_avgtime'] = taxiTime(sample)
sample
# Out:
# C:\Applications\Anaconda\lib\site-packages\numpy\core\fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Applications\Anaconda\lib\site-packages\numpy\core\_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#    LocationID  lon_pickup  lat_pickup  LocationID2  lon_dropoff  lat_dropoff  \
# 0         110  -74.128342   40.545780          254   -73.858948    40.882157
# 1          51  -73.828264   40.873973           92   -73.828859    40.761102
# 2         166  -73.961764   40.809457          234   -73.990458    40.740337
# 3         207  -73.899353   40.763986          248   -73.872289    40.834165
# 4         195  -74.009178   40.675549           68   -73.999917    40.748428
# 5         251  -74.125348   40.616880          114   -73.997380    40.728340
# 6          71  -73.937966   40.644288          118   -74.132979    40.586555
# 7         139  -73.744234   40.677098          202   -73.949952    40.761900
# 8          76  -73.876821   40.660935          240   -73.881978    40.894599
# 9         165  -73.956825   40.620924          258   -73.855767    40.688721
#
#    driving_time  TLC_avgtime
# 0          3877          NaN
# 1          1252  1398.000000
# 2          1102  1834.531062
# 3          1139          NaN
# 4          1040  2149.000000
# 5          1824          NaN
# 6          1940  3126.000000
# 7          2066          NaN
# 8          2350  3203.666667
# 9          1724  2622.000000

# %% [markdown]
# ### Homework - extracredit
#
# 1. Extract 2018/2019 FHV and shared FHV data and compare with taxi times from TLC and driving times from HereMap API for 50 random O-D pairs.
# 2. Using geocoding API from HereMAPs

# %% [markdown]
# ### Retrieving FHV and shared FHV data
#
# #### FHV (for hire vehicles) refers to cars belonging to privately owned companies and entities like Uber, Lyft etc. Shared for hire vehicles (SFHV) trips are where two or more people share the same trip (UberPool etc.)
#
#
# use API endpoint: https://data.cityofnewyork.us/resource/u6nh-b56h.json
#
# for shared FHV, use parameter 'SR_flag': 1 and 0 for non shared FHV

# %% [markdown]
# ### Task 1: get sample request for a single O-D pair for both FHV and shared FHV

# %%
# write parameters here for FHV
parameter = {'pulocationid':162, 'dolocationid':1,'sr_flag':1}

# %%
# code here, get travel time from one observation for above O-D pair

# %%
url =  "https://data.cityofnewyork.us/resource/u6nh-b56h.json"
r = requests.get(url = url, params=parameter)
FHV = r.json()

# %%
FHV
# Out:
# [{'dispatching_base_num': 'B02835',
#   'pickup_datetime': '2019-01-01T01:51:19.000',
#   'dropoff_datetime': '2019-01-01T02:37:34.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-01T04:01:07.000',
#   'dropoff_datetime': '2019-01-01T04:34:46.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-01T06:49:03.000',
#   'dropoff_datetime': '2019-01-01T07:18:55.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-02T11:54:21.000',
#   'dropoff_datetime': '2019-01-02T12:36:38.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-02T12:41:05.000',
#   'dropoff_datetime': '2019-01-02T13:38:55.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-02T16:01:34.000',
#   'dropoff_datetime': '2019-01-02T16:53:51.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-02T17:06:32.000',
#   'dropoff_datetime': '2019-01-02T18:07:35.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-02T17:01:46.000',
#   'dropoff_datetime': '2019-01-02T18:17:26.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-03T14:16:16.000',
#   'dropoff_datetime': '2019-01-03T15:19:19.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-03T16:09:57.000',
#   'dropoff_datetime': '2019-01-03T17:07:41.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-04T10:07:46.000',
#   'dropoff_datetime': '2019-01-04T10:53:59.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-04T17:13:53.000',
#   'dropoff_datetime': '2019-01-04T18:15:09.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-05T10:42:52.000',
#   'dropoff_datetime': '2019-01-05T11:32:29.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-06T07:13:23.000',
#   'dropoff_datetime': '2019-01-06T07:48:28.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-06T19:28:25.000',
#   'dropoff_datetime': '2019-01-06T20:04:06.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-07T06:02:06.000',
#   'dropoff_datetime': '2019-01-07T06:26:53.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-07T17:57:53.000',
#   'dropoff_datetime': '2019-01-07T18:37:47.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-08T08:04:14.000',
#   'dropoff_datetime': '2019-01-08T08:53:27.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-08T18:47:37.000',
#   'dropoff_datetime': '2019-01-08T20:30:38.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-10T15:30:38.000',
#   'dropoff_datetime': '2019-01-10T16:28:37.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02869',
#   'pickup_datetime': '2019-01-12T00:26:23.000',
#   'dropoff_datetime': '2019-01-12T01:11:21.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-17T15:17:50.000',
#   'dropoff_datetime': '2019-01-17T16:35:25.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-19T09:46:31.000',
#   'dropoff_datetime': '2019-01-19T10:40:46.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-20T04:24:54.000',
#   'dropoff_datetime': '2019-01-20T05:14:55.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-20T06:57:04.000',
#   'dropoff_datetime': '2019-01-20T07:38:48.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-20T08:12:13.000',
#   'dropoff_datetime': '2019-01-20T08:44:44.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-20T18:40:02.000',
#   'dropoff_datetime': '2019-01-20T19:35:00.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-21T07:32:38.000',
#   'dropoff_datetime': '2019-01-21T08:17:22.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-24T14:02:30.000',
#   'dropoff_datetime': '2019-01-24T15:02:51.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-27T06:32:29.000',
#   'dropoff_datetime': '2019-01-27T07:12:06.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-27T12:30:01.000',
#   'dropoff_datetime': '2019-01-27T13:26:44.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-28T06:51:19.000',
#   'dropoff_datetime': '2019-01-28T07:26:41.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-29T15:22:15.000',
#   'dropoff_datetime': '2019-01-29T16:38:30.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-30T07:43:46.000',
#   'dropoff_datetime': '2019-01-30T08:29:17.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-31T16:32:56.000',
#   'dropoff_datetime': '2019-01-31T17:16:26.000',
#   'pulocationid': '162',
#   'dolocationid': '1',
#   'sr_flag': '1'}]

# %%
parser.parse(FHV[0]['dropoff_datetime']) - parser.parse(FHV[0]['pickup_datetime'])
# Out:
# datetime.timedelta(seconds=2775)

# %%
str(parser.parse(FHV[0]['dropoff_datetime']) - parser.parse(FHV[0]['pickup_datetime']))
# Out:
# '0:46:15'

# %%
# write parameters here for shared FHV
parameter0 = {'pulocationid':210, 'dolocationid':91, 'sr_flag':1 }

# %%
# get shared FHV travel time from one observation for above O-D pair
url =  "https://data.cityofnewyork.us/resource/u6nh-b56h.json"
R = requests.get(url = url, params=parameter0)
SFHV = R.json()

# %%
SFHV
# Out:
# [{'dispatching_base_num': 'B02395',
#   'pickup_datetime': '2019-01-01T00:49:31.000',
#   'dropoff_datetime': '2019-01-01T01:11:41.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02876',
#   'pickup_datetime': '2019-01-01T00:07:37.000',
#   'dropoff_datetime': '2019-01-01T00:20:38.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02869',
#   'pickup_datetime': '2019-01-01T01:17:10.000',
#   'dropoff_datetime': '2019-01-01T01:28:40.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-01T02:39:08.000',
#   'dropoff_datetime': '2019-01-01T02:47:05.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02870',
#   'pickup_datetime': '2019-01-01T10:59:05.000',
#   'dropoff_datetime': '2019-01-01T11:14:27.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02884',
#   'pickup_datetime': '2019-01-01T20:39:51.000',
#   'dropoff_datetime': '2019-01-01T20:57:52.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-02T02:52:40.000',
#   'dropoff_datetime': '2019-01-02T03:06:01.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02877',
#   'pickup_datetime': '2019-01-02T07:01:42.000',
#   'dropoff_datetime': '2019-01-02T07:23:49.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-02T15:35:38.000',
#   'dropoff_datetime': '2019-01-02T15:53:00.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02867',
#   'pickup_datetime': '2019-01-02T16:22:57.000',
#   'dropoff_datetime': '2019-01-02T16:39:54.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02866',
#   'pickup_datetime': '2019-01-02T21:11:13.000',
#   'dropoff_datetime': '2019-01-02T21:34:40.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02883',
#   'pickup_datetime': '2019-01-02T22:48:00.000',
#   'dropoff_datetime': '2019-01-02T23:05:10.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-03T08:30:35.000',
#   'dropoff_datetime': '2019-01-03T08:40:11.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02875',
#   'pickup_datetime': '2019-01-03T09:56:41.000',
#   'dropoff_datetime': '2019-01-03T10:12:11.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-03T12:11:15.000',
#   'dropoff_datetime': '2019-01-03T12:22:45.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02884',
#   'pickup_datetime': '2019-01-03T13:56:12.000',
#   'dropoff_datetime': '2019-01-03T14:12:35.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-03T14:56:21.000',
#   'dropoff_datetime': '2019-01-03T15:13:35.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02887',
#   'pickup_datetime': '2019-01-03T20:37:21.000',
#   'dropoff_datetime': '2019-01-03T20:48:32.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02872',
#   'pickup_datetime': '2019-01-04T20:54:06.000',
#   'dropoff_datetime': '2019-01-04T21:16:47.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-04T21:14:51.000',
#   'dropoff_datetime': '2019-01-04T21:27:58.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02878',
#   'pickup_datetime': '2019-01-04T22:34:43.000',
#   'dropoff_datetime': '2019-01-04T22:51:52.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02883',
#   'pickup_datetime': '2019-01-05T00:21:20.000',
#   'dropoff_datetime': '2019-01-05T00:34:05.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-05T01:20:01.000',
#   'dropoff_datetime': '2019-01-05T01:27:57.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02871',
#   'pickup_datetime': '2019-01-05T02:44:48.000',
#   'dropoff_datetime': '2019-01-05T03:02:35.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-05T08:43:13.000',
#   'dropoff_datetime': '2019-01-05T08:52:11.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02835',
#   'pickup_datetime': '2019-01-05T08:38:24.000',
#   'dropoff_datetime': '2019-01-05T08:52:58.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-05T11:45:43.000',
#   'dropoff_datetime': '2019-01-05T12:03:57.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-05T21:14:56.000',
#   'dropoff_datetime': '2019-01-05T21:26:13.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-05T22:31:09.000',
#   'dropoff_datetime': '2019-01-05T22:46:41.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02866',
#   'pickup_datetime': '2019-01-05T22:14:50.000',
#   'dropoff_datetime': '2019-01-05T22:42:21.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02876',
#   'pickup_datetime': '2019-01-05T22:41:25.000',
#   'dropoff_datetime': '2019-01-05T22:58:56.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-05T23:00:49.000',
#   'dropoff_datetime': '2019-01-05T23:12:29.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-06T00:52:18.000',
#   'dropoff_datetime': '2019-01-06T00:58:59.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02864',
#   'pickup_datetime': '2019-01-06T05:54:53.000',
#   'dropoff_datetime': '2019-01-06T06:11:23.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02866',
#   'pickup_datetime': '2019-01-06T12:17:58.000',
#   'dropoff_datetime': '2019-01-06T12:37:00.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-06T14:26:08.000',
#   'dropoff_datetime': '2019-01-06T14:51:06.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02875',
#   'pickup_datetime': '2019-01-06T15:03:58.000',
#   'dropoff_datetime': '2019-01-06T15:21:15.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-06T17:13:16.000',
#   'dropoff_datetime': '2019-01-06T17:41:19.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-06T17:34:23.000',
#   'dropoff_datetime': '2019-01-06T17:49:35.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02876',
#   'pickup_datetime': '2019-01-06T17:47:25.000',
#   'dropoff_datetime': '2019-01-06T18:00:17.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-06T18:02:21.000',
#   'dropoff_datetime': '2019-01-06T18:26:01.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-06T19:10:55.000',
#   'dropoff_datetime': '2019-01-06T19:31:00.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02866',
#   'pickup_datetime': '2019-01-07T00:36:48.000',
#   'dropoff_datetime': '2019-01-07T01:03:06.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-07T08:40:04.000',
#   'dropoff_datetime': '2019-01-07T08:57:32.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-07T20:56:10.000',
#   'dropoff_datetime': '2019-01-07T21:14:47.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02871',
#   'pickup_datetime': '2019-01-07T21:19:19.000',
#   'dropoff_datetime': '2019-01-07T21:39:32.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02887',
#   'pickup_datetime': '2019-01-07T22:18:34.000',
#   'dropoff_datetime': '2019-01-07T22:32:34.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02882',
#   'pickup_datetime': '2019-01-08T06:34:42.000',
#   'dropoff_datetime': '2019-01-08T06:57:29.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02865',
#   'pickup_datetime': '2019-01-08T07:20:50.000',
#   'dropoff_datetime': '2019-01-08T07:39:10.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02869',
#   'pickup_datetime': '2019-01-08T07:10:52.000',
#   'dropoff_datetime': '2019-01-08T07:28:18.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02887',
#   'pickup_datetime': '2019-01-08T09:52:43.000',
#   'dropoff_datetime': '2019-01-08T10:06:59.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-08T14:42:07.000',
#   'dropoff_datetime': '2019-01-08T15:04:52.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-08T15:21:34.000',
#   'dropoff_datetime': '2019-01-08T15:42:54.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02872',
#   'pickup_datetime': '2019-01-08T16:48:24.000',
#   'dropoff_datetime': '2019-01-08T17:06:59.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02871',
#   'pickup_datetime': '2019-01-08T17:17:42.000',
#   'dropoff_datetime': '2019-01-08T17:39:01.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02869',
#   'pickup_datetime': '2019-01-08T21:00:22.000',
#   'dropoff_datetime': '2019-01-08T21:09:36.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02864',
#   'pickup_datetime': '2019-01-09T05:04:47.000',
#   'dropoff_datetime': '2019-01-09T05:19:46.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02871',
#   'pickup_datetime': '2019-01-09T07:40:13.000',
#   'dropoff_datetime': '2019-01-09T08:15:42.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-09T08:33:08.000',
#   'dropoff_datetime': '2019-01-09T08:43:04.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-09T12:43:20.000',
#   'dropoff_datetime': '2019-01-09T13:02:35.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-09T14:01:01.000',
#   'dropoff_datetime': '2019-01-09T14:13:26.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02878',
#   'pickup_datetime': '2019-01-09T17:41:49.000',
#   'dropoff_datetime': '2019-01-09T18:04:09.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-09T21:25:37.000',
#   'dropoff_datetime': '2019-01-09T21:42:05.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-10T07:46:19.000',
#   'dropoff_datetime': '2019-01-10T07:59:34.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02867',
#   'pickup_datetime': '2019-01-10T09:56:44.000',
#   'dropoff_datetime': '2019-01-10T10:08:29.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-10T10:51:11.000',
#   'dropoff_datetime': '2019-01-10T11:04:58.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02887',
#   'pickup_datetime': '2019-01-10T10:17:52.000',
#   'dropoff_datetime': '2019-01-10T10:46:32.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02877',
#   'pickup_datetime': '2019-01-10T17:13:15.000',
#   'dropoff_datetime': '2019-01-10T17:29:25.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02875',
#   'pickup_datetime': '2019-01-10T22:46:46.000',
#   'dropoff_datetime': '2019-01-10T23:02:11.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-10T23:31:11.000',
#   'dropoff_datetime': '2019-01-10T23:47:29.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-11T00:54:03.000',
#   'dropoff_datetime': '2019-01-11T01:15:57.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-11T07:09:34.000',
#   'dropoff_datetime': '2019-01-11T07:32:05.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-11T08:35:18.000',
#   'dropoff_datetime': '2019-01-11T08:46:40.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02866',
#   'pickup_datetime': '2019-01-11T11:02:05.000',
#   'dropoff_datetime': '2019-01-11T12:13:13.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02876',
#   'pickup_datetime': '2019-01-11T14:35:07.000',
#   'dropoff_datetime': '2019-01-11T15:24:19.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02889',
#   'pickup_datetime': '2019-01-11T15:11:07.000',
#   'dropoff_datetime': '2019-01-11T15:33:01.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02866',
#   'pickup_datetime': '2019-01-11T16:35:16.000',
#   'dropoff_datetime': '2019-01-11T16:50:24.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-11T17:27:06.000',
#   'dropoff_datetime': '2019-01-11T18:03:21.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02836',
#   'pickup_datetime': '2019-01-11T17:55:08.000',
#   'dropoff_datetime': '2019-01-11T18:15:45.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02889',
#   'pickup_datetime': '2019-01-11T18:45:38.000',
#   'dropoff_datetime': '2019-01-11T19:09:35.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02884',
#   'pickup_datetime': '2019-01-11T20:50:22.000',
#   'dropoff_datetime': '2019-01-11T21:04:57.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02883',
#   'pickup_datetime': '2019-01-11T21:03:41.000',
#   'dropoff_datetime': '2019-01-11T21:16:22.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-11T22:23:46.000',
#   'dropoff_datetime': '2019-01-11T22:36:53.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02888',
#   'pickup_datetime': '2019-01-11T23:09:56.000',
#   'dropoff_datetime': '2019-01-11T23:25:37.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02889',
#   'pickup_datetime': '2019-01-12T03:52:32.000',
#   'dropoff_datetime': '2019-01-12T04:07:20.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-12T08:31:14.000',
#   'dropoff_datetime': '2019-01-12T08:41:03.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02872',
#   'pickup_datetime': '2019-01-12T13:34:56.000',
#   'dropoff_datetime': '2019-01-12T13:53:39.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02875',
#   'pickup_datetime': '2019-01-12T13:47:50.000',
#   'dropoff_datetime': '2019-01-12T14:03:45.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02871',
#   'pickup_datetime': '2019-01-12T15:13:10.000',
#   'dropoff_datetime': '2019-01-12T15:26:33.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-12T18:40:07.000',
#   'dropoff_datetime': '2019-01-12T19:05:39.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02871',
#   'pickup_datetime': '2019-01-12T18:43:41.000',
#   'dropoff_datetime': '2019-01-12T18:57:43.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-12T20:02:40.000',
#   'dropoff_datetime': '2019-01-12T20:19:56.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02889',
#   'pickup_datetime': '2019-01-12T22:50:55.000',
#   'dropoff_datetime': '2019-01-12T23:04:52.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-13T04:37:21.000',
#   'dropoff_datetime': '2019-01-13T04:57:50.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-13T18:21:02.000',
#   'dropoff_datetime': '2019-01-13T18:45:39.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-14T07:01:18.000',
#   'dropoff_datetime': '2019-01-14T07:10:40.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-14T08:34:48.000',
#   'dropoff_datetime': '2019-01-14T08:45:16.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-14T10:04:09.000',
#   'dropoff_datetime': '2019-01-14T10:16:35.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-14T10:14:03.000',
#   'dropoff_datetime': '2019-01-14T10:26:04.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02836',
#   'pickup_datetime': '2019-01-14T14:51:40.000',
#   'dropoff_datetime': '2019-01-14T15:11:29.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-14T15:04:05.000',
#   'dropoff_datetime': '2019-01-14T15:16:37.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02866',
#   'pickup_datetime': '2019-01-14T15:11:40.000',
#   'dropoff_datetime': '2019-01-14T15:32:17.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02883',
#   'pickup_datetime': '2019-01-14T15:29:57.000',
#   'dropoff_datetime': '2019-01-14T15:46:55.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02867',
#   'pickup_datetime': '2019-01-14T16:40:06.000',
#   'dropoff_datetime': '2019-01-14T16:58:30.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-14T18:11:44.000',
#   'dropoff_datetime': '2019-01-14T18:34:13.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02887',
#   'pickup_datetime': '2019-01-14T20:37:55.000',
#   'dropoff_datetime': '2019-01-14T20:48:58.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02836',
#   'pickup_datetime': '2019-01-15T00:44:20.000',
#   'dropoff_datetime': '2019-01-15T00:58:04.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02876',
#   'pickup_datetime': '2019-01-15T07:15:47.000',
#   'dropoff_datetime': '2019-01-15T07:37:48.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-15T08:27:49.000',
#   'dropoff_datetime': '2019-01-15T08:38:43.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02512',
#   'pickup_datetime': '2019-01-15T13:14:56.000',
#   'dropoff_datetime': '2019-01-15T13:31:18.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-15T15:34:44.000',
#   'dropoff_datetime': '2019-01-15T15:47:36.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-15T15:37:42.000',
#   'dropoff_datetime': '2019-01-15T15:55:29.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02876',
#   'pickup_datetime': '2019-01-15T17:07:56.000',
#   'dropoff_datetime': '2019-01-15T17:38:19.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-15T19:54:36.000',
#   'dropoff_datetime': '2019-01-15T20:03:57.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02875',
#   'pickup_datetime': '2019-01-15T19:24:12.000',
#   'dropoff_datetime': '2019-01-15T19:40:43.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-16T01:06:42.000',
#   'dropoff_datetime': '2019-01-16T01:31:23.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-16T07:30:54.000',
#   'dropoff_datetime': '2019-01-16T07:44:06.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02836',
#   'pickup_datetime': '2019-01-16T08:55:58.000',
#   'dropoff_datetime': '2019-01-16T09:11:15.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02875',
#   'pickup_datetime': '2019-01-16T09:14:08.000',
#   'dropoff_datetime': '2019-01-16T09:27:50.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-16T13:31:49.000',
#   'dropoff_datetime': '2019-01-16T13:51:18.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02866',
#   'pickup_datetime': '2019-01-16T15:16:01.000',
#   'dropoff_datetime': '2019-01-16T15:37:24.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02869',
#   'pickup_datetime': '2019-01-16T18:47:31.000',
#   'dropoff_datetime': '2019-01-16T19:12:57.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02871',
#   'pickup_datetime': '2019-01-16T21:41:01.000',
#   'dropoff_datetime': '2019-01-16T21:53:58.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02875',
#   'pickup_datetime': '2019-01-16T22:03:39.000',
#   'dropoff_datetime': '2019-01-16T22:12:52.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02875',
#   'pickup_datetime': '2019-01-17T09:06:18.000',
#   'dropoff_datetime': '2019-01-17T09:23:34.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-17T14:24:18.000',
#   'dropoff_datetime': '2019-01-17T14:32:38.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-17T15:39:23.000',
#   'dropoff_datetime': '2019-01-17T16:08:57.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02872',
#   'pickup_datetime': '2019-01-17T15:18:48.000',
#   'dropoff_datetime': '2019-01-17T15:34:16.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02871',
#   'pickup_datetime': '2019-01-17T16:10:28.000',
#   'dropoff_datetime': '2019-01-17T16:28:46.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02869',
#   'pickup_datetime': '2019-01-17T18:02:41.000',
#   'dropoff_datetime': '2019-01-17T18:18:33.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02871',
#   'pickup_datetime': '2019-01-17T22:03:37.000',
#   'dropoff_datetime': '2019-01-17T22:24:02.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02682',
#   'pickup_datetime': '2019-01-18T06:35:56.000',
#   'dropoff_datetime': '2019-01-18T06:51:15.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-18T08:35:15.000',
#   'dropoff_datetime': '2019-01-18T08:44:48.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02867',
#   'pickup_datetime': '2019-01-18T08:36:43.000',
#   'dropoff_datetime': '2019-01-18T08:57:28.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-18T09:47:27.000',
#   'dropoff_datetime': '2019-01-18T10:00:04.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02871',
#   'pickup_datetime': '2019-01-18T11:49:26.000',
#   'dropoff_datetime': '2019-01-18T12:08:45.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-18T17:45:00.000',
#   'dropoff_datetime': '2019-01-18T18:02:32.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02865',
#   'pickup_datetime': '2019-01-18T17:03:38.000',
#   'dropoff_datetime': '2019-01-18T17:28:54.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02864',
#   'pickup_datetime': '2019-01-18T19:01:49.000',
#   'dropoff_datetime': '2019-01-18T19:32:44.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02871',
#   'pickup_datetime': '2019-01-18T19:26:10.000',
#   'dropoff_datetime': '2019-01-18T19:48:46.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-18T21:59:26.000',
#   'dropoff_datetime': '2019-01-18T22:09:24.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02887',
#   'pickup_datetime': '2019-01-18T21:25:32.000',
#   'dropoff_datetime': '2019-01-18T21:39:41.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02889',
#   'pickup_datetime': '2019-01-18T23:48:18.000',
#   'dropoff_datetime': '2019-01-19T00:07:52.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-19T06:25:22.000',
#   'dropoff_datetime': '2019-01-19T06:39:01.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02866',
#   'pickup_datetime': '2019-01-19T09:57:30.000',
#   'dropoff_datetime': '2019-01-19T10:22:57.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-19T16:37:32.000',
#   'dropoff_datetime': '2019-01-19T17:00:25.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02869',
#   'pickup_datetime': '2019-01-19T18:02:57.000',
#   'dropoff_datetime': '2019-01-19T18:34:18.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02889',
#   'pickup_datetime': '2019-01-19T20:37:34.000',
#   'dropoff_datetime': '2019-01-19T20:53:47.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02871',
#   'pickup_datetime': '2019-01-19T21:27:54.000',
#   'dropoff_datetime': '2019-01-19T21:44:26.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02871',
#   'pickup_datetime': '2019-01-19T23:43:18.000',
#   'dropoff_datetime': '2019-01-20T00:02:37.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-20T00:28:15.000',
#   'dropoff_datetime': '2019-01-20T00:30:27.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02869',
#   'pickup_datetime': '2019-01-20T00:31:23.000',
#   'dropoff_datetime': '2019-01-20T00:47:23.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-20T06:14:18.000',
#   'dropoff_datetime': '2019-01-20T06:26:40.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02884',
#   'pickup_datetime': '2019-01-20T08:34:26.000',
#   'dropoff_datetime': '2019-01-20T08:47:26.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02875',
#   'pickup_datetime': '2019-01-20T09:10:28.000',
#   'dropoff_datetime': '2019-01-20T09:34:01.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-20T10:45:57.000',
#   'dropoff_datetime': '2019-01-20T10:59:30.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-20T14:37:28.000',
#   'dropoff_datetime': '2019-01-20T14:59:11.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02872',
#   'pickup_datetime': '2019-01-20T16:56:00.000',
#   'dropoff_datetime': '2019-01-20T17:23:54.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02884',
#   'pickup_datetime': '2019-01-20T16:03:09.000',
#   'dropoff_datetime': '2019-01-20T16:20:56.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-20T20:18:01.000',
#   'dropoff_datetime': '2019-01-20T20:31:27.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-20T22:32:44.000',
#   'dropoff_datetime': '2019-01-20T22:46:13.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02866',
#   'pickup_datetime': '2019-01-20T22:30:49.000',
#   'dropoff_datetime': '2019-01-20T22:45:32.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02872',
#   'pickup_datetime': '2019-01-20T23:43:16.000',
#   'dropoff_datetime': '2019-01-20T23:54:43.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02875',
#   'pickup_datetime': '2019-01-21T00:13:28.000',
#   'dropoff_datetime': '2019-01-21T00:26:58.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-21T06:29:03.000',
#   'dropoff_datetime': '2019-01-21T06:48:08.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-21T08:36:40.000',
#   'dropoff_datetime': '2019-01-21T08:45:55.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02889',
#   'pickup_datetime': '2019-01-21T08:06:16.000',
#   'dropoff_datetime': '2019-01-21T08:23:10.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02869',
#   'pickup_datetime': '2019-01-21T09:54:30.000',
#   'dropoff_datetime': '2019-01-21T10:18:28.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02883',
#   'pickup_datetime': '2019-01-21T13:09:55.000',
#   'dropoff_datetime': '2019-01-21T13:28:05.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02879',
#   'pickup_datetime': '2019-01-21T14:39:13.000',
#   'dropoff_datetime': '2019-01-21T14:54:39.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02877',
#   'pickup_datetime': '2019-01-21T15:00:35.000',
#   'dropoff_datetime': '2019-01-21T15:16:35.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-21T17:19:11.000',
#   'dropoff_datetime': '2019-01-21T17:26:56.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02872',
#   'pickup_datetime': '2019-01-21T17:05:45.000',
#   'dropoff_datetime': '2019-01-21T17:32:33.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02878',
#   'pickup_datetime': '2019-01-21T11:43:35.000',
#   'dropoff_datetime': '2019-01-21T12:09:50.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-21T19:44:33.000',
#   'dropoff_datetime': '2019-01-21T20:16:32.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02875',
#   'pickup_datetime': '2019-01-21T20:04:39.000',
#   'dropoff_datetime': '2019-01-21T20:21:50.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-21T21:01:04.000',
#   'dropoff_datetime': '2019-01-21T21:16:57.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-21T22:31:13.000',
#   'dropoff_datetime': '2019-01-21T22:40:30.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-21T23:08:22.000',
#   'dropoff_datetime': '2019-01-21T23:24:02.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02875',
#   'pickup_datetime': '2019-01-22T15:21:40.000',
#   'dropoff_datetime': '2019-01-22T15:48:07.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02872',
#   'pickup_datetime': '2019-01-22T20:40:13.000',
#   'dropoff_datetime': '2019-01-22T20:54:16.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-22T21:28:15.000',
#   'dropoff_datetime': '2019-01-22T21:47:14.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-22T22:43:41.000',
#   'dropoff_datetime': '2019-01-22T22:55:06.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-22T22:24:59.000',
#   'dropoff_datetime': '2019-01-22T22:41:15.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-22T22:55:32.000',
#   'dropoff_datetime': '2019-01-22T23:12:50.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02884',
#   'pickup_datetime': '2019-01-23T00:21:02.000',
#   'dropoff_datetime': '2019-01-23T00:40:46.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-23T08:37:57.000',
#   'dropoff_datetime': '2019-01-23T08:49:31.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02512',
#   'pickup_datetime': '2019-01-23T10:36:35.000',
#   'dropoff_datetime': '2019-01-23T10:50:04.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02871',
#   'pickup_datetime': '2019-01-23T13:19:09.000',
#   'dropoff_datetime': '2019-01-23T13:35:59.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02864',
#   'pickup_datetime': '2019-01-23T14:25:29.000',
#   'dropoff_datetime': '2019-01-23T14:41:08.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02867',
#   'pickup_datetime': '2019-01-23T17:29:11.000',
#   'dropoff_datetime': '2019-01-23T17:53:23.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02883',
#   'pickup_datetime': '2019-01-24T00:45:22.000',
#   'dropoff_datetime': '2019-01-24T00:57:51.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02879',
#   'pickup_datetime': '2019-01-24T14:40:20.000',
#   'dropoff_datetime': '2019-01-24T14:59:17.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02877',
#   'pickup_datetime': '2019-01-24T16:24:13.000',
#   'dropoff_datetime': '2019-01-24T16:36:42.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02889',
#   'pickup_datetime': '2019-01-24T16:31:18.000',
#   'dropoff_datetime': '2019-01-24T16:46:32.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02871',
#   'pickup_datetime': '2019-01-24T17:07:21.000',
#   'dropoff_datetime': '2019-01-24T17:33:39.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-24T18:31:27.000',
#   'dropoff_datetime': '2019-01-24T18:50:59.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02887',
#   'pickup_datetime': '2019-01-24T18:47:51.000',
#   'dropoff_datetime': '2019-01-24T19:03:22.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-24T19:57:36.000',
#   'dropoff_datetime': '2019-01-24T20:26:57.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02869',
#   'pickup_datetime': '2019-01-24T21:33:39.000',
#   'dropoff_datetime': '2019-01-24T21:46:03.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02871',
#   'pickup_datetime': '2019-01-24T21:15:49.000',
#   'dropoff_datetime': '2019-01-24T21:30:15.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-25T07:13:38.000',
#   'dropoff_datetime': '2019-01-25T07:36:17.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-25T08:26:25.000',
#   'dropoff_datetime': '2019-01-25T08:35:57.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-25T15:29:49.000',
#   'dropoff_datetime': '2019-01-25T15:37:26.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02866',
#   'pickup_datetime': '2019-01-25T15:34:55.000',
#   'dropoff_datetime': '2019-01-25T16:13:49.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-25T18:51:04.000',
#   'dropoff_datetime': '2019-01-25T19:09:03.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02877',
#   'pickup_datetime': '2019-01-25T18:47:57.000',
#   'dropoff_datetime': '2019-01-25T19:08:47.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-25T21:08:37.000',
#   'dropoff_datetime': '2019-01-25T21:17:53.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02875',
#   'pickup_datetime': '2019-01-25T21:21:48.000',
#   'dropoff_datetime': '2019-01-25T21:38:25.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02875',
#   'pickup_datetime': '2019-01-25T21:22:36.000',
#   'dropoff_datetime': '2019-01-25T21:42:57.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02836',
#   'pickup_datetime': '2019-01-26T00:26:26.000',
#   'dropoff_datetime': '2019-01-26T00:37:00.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-26T01:39:42.000',
#   'dropoff_datetime': '2019-01-26T01:58:52.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-26T08:28:12.000',
#   'dropoff_datetime': '2019-01-26T08:37:37.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02875',
#   'pickup_datetime': '2019-01-26T11:07:08.000',
#   'dropoff_datetime': '2019-01-26T11:28:00.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-26T14:06:12.000',
#   'dropoff_datetime': '2019-01-26T14:22:07.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02887',
#   'pickup_datetime': '2019-01-26T14:01:23.000',
#   'dropoff_datetime': '2019-01-26T14:13:03.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-26T20:34:08.000',
#   'dropoff_datetime': '2019-01-26T20:54:53.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-26T23:35:14.000',
#   'dropoff_datetime': '2019-01-26T23:56:11.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02872',
#   'pickup_datetime': '2019-01-27T01:07:53.000',
#   'dropoff_datetime': '2019-01-27T01:27:11.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02867',
#   'pickup_datetime': '2019-01-27T09:40:34.000',
#   'dropoff_datetime': '2019-01-27T10:00:26.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02876',
#   'pickup_datetime': '2019-01-27T10:11:35.000',
#   'dropoff_datetime': '2019-01-27T10:26:42.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02866',
#   'pickup_datetime': '2019-01-27T13:19:20.000',
#   'dropoff_datetime': '2019-01-27T13:31:30.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-27T16:46:34.000',
#   'dropoff_datetime': '2019-01-27T17:00:35.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02876',
#   'pickup_datetime': '2019-01-27T21:02:15.000',
#   'dropoff_datetime': '2019-01-27T21:21:41.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02877',
#   'pickup_datetime': '2019-01-27T22:41:41.000',
#   'dropoff_datetime': '2019-01-27T22:53:44.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02878',
#   'pickup_datetime': '2019-01-27T22:11:50.000',
#   'dropoff_datetime': '2019-01-27T22:29:13.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-28T06:59:15.000',
#   'dropoff_datetime': '2019-01-28T07:11:54.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02869',
#   'pickup_datetime': '2019-01-28T07:12:48.000',
#   'dropoff_datetime': '2019-01-28T07:28:08.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02867',
#   'pickup_datetime': '2019-01-28T08:21:33.000',
#   'dropoff_datetime': '2019-01-28T08:34:55.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02835',
#   'pickup_datetime': '2019-01-28T16:13:27.000',
#   'dropoff_datetime': '2019-01-28T16:30:04.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02867',
#   'pickup_datetime': '2019-01-28T17:59:14.000',
#   'dropoff_datetime': '2019-01-28T18:16:33.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02765',
#   'pickup_datetime': '2019-01-28T18:24:51.000',
#   'dropoff_datetime': '2019-01-28T18:33:39.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02882',
#   'pickup_datetime': '2019-01-28T18:05:12.000',
#   'dropoff_datetime': '2019-01-28T18:29:06.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02887',
#   'pickup_datetime': '2019-01-28T18:41:08.000',
#   'dropoff_datetime': '2019-01-28T19:05:26.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-29T07:35:10.000',
#   'dropoff_datetime': '2019-01-29T07:46:34.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02878',
#   'pickup_datetime': '2019-01-29T09:56:41.000',
#   'dropoff_datetime': '2019-01-29T10:09:57.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02867',
#   'pickup_datetime': '2019-01-29T10:02:07.000',
#   'dropoff_datetime': '2019-01-29T10:12:55.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02879',
#   'pickup_datetime': '2019-01-29T18:10:44.000',
#   'dropoff_datetime': '2019-01-29T18:30:20.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02764',
#   'pickup_datetime': '2019-01-29T20:40:46.000',
#   'dropoff_datetime': '2019-01-29T20:51:53.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02872',
#   'pickup_datetime': '2019-01-29T20:55:57.000',
#   'dropoff_datetime': '2019-01-29T21:15:48.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-30T07:50:01.000',
#   'dropoff_datetime': '2019-01-30T08:01:50.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-30T08:32:16.000',
#   'dropoff_datetime': '2019-01-30T08:57:06.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02866',
#   'pickup_datetime': '2019-01-30T08:12:35.000',
#   'dropoff_datetime': '2019-01-30T08:38:39.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02878',
#   'pickup_datetime': '2019-01-30T08:23:52.000',
#   'dropoff_datetime': '2019-01-30T08:37:22.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02617',
#   'pickup_datetime': '2019-01-30T16:27:09.000',
#   'dropoff_datetime': '2019-01-30T16:58:33.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-31T00:24:14.000',
#   'dropoff_datetime': '2019-01-31T00:31:34.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02889',
#   'pickup_datetime': '2019-01-31T07:15:39.000',
#   'dropoff_datetime': '2019-01-31T07:32:40.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-31T08:31:55.000',
#   'dropoff_datetime': '2019-01-31T08:51:25.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02889',
#   'pickup_datetime': '2019-01-31T13:38:39.000',
#   'dropoff_datetime': '2019-01-31T14:00:34.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02510',
#   'pickup_datetime': '2019-01-31T14:27:52.000',
#   'dropoff_datetime': '2019-01-31T14:38:25.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02871',
#   'pickup_datetime': '2019-01-31T16:47:19.000',
#   'dropoff_datetime': '2019-01-31T17:01:54.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02875',
#   'pickup_datetime': '2019-01-31T16:33:57.000',
#   'dropoff_datetime': '2019-01-31T16:52:52.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02871',
#   'pickup_datetime': '2019-01-31T21:04:57.000',
#   'dropoff_datetime': '2019-01-31T21:27:42.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'},
#  {'dispatching_base_num': 'B02889',
#   'pickup_datetime': '2019-01-31T21:05:50.000',
#   'dropoff_datetime': '2019-01-31T21:19:10.000',
#   'pulocationid': '210',
#   'dolocationid': '91',
#   'sr_flag': '1'}]

# %%
parser.parse(SFHV[0]['dropoff_datetime']) - parser.parse(SFHV[0]['pickup_datetime'])
# Out:
# datetime.timedelta(seconds=1330)

# %%
str(parser.parse(SFHV[0]['dropoff_datetime']) - parser.parse(SFHV[0]['pickup_datetime']))
# Out:
# '0:22:10'

# %% [markdown]
# ### Task 2. Write the function for getting FHV and Shared FHV times for 50 sample O-D pairs.
#
# #### Hint: see above that the returned FHV/shared FHV data has column names 'pickup_datetime' and 'dropoff_datetime' instead of 'tpep_pickup_datetime' and 'tpep_dropoff_datetime' used in the functions above. So make sure to change these names when writing the code below
#
#
# Also make necessary filtering to remove outliers. Remember, in this data, just travel times are available, so we don't need any other variable outlier filtering.

# %%
# sample points

df = pd.read_csv('https://raw.githubusercontent.com/CUSP2020PUI/Data/master/samplePoints.csv')
sample = df.sample(50, random_state=2020)
sample.head()
# Out:
#      LocationID  lon_pickup  lat_pickup  LocationID2  lon_dropoff  lat_dropoff
# 109         110  -74.128342   40.545780          254   -73.858948    40.882157
# 50           51  -73.828264   40.873973           92   -73.828859    40.761102
# 165         166  -73.961764   40.809457          234   -73.990458    40.740337
# 206         207  -73.899353   40.763986          248   -73.872289    40.834165
# 194         195  -74.009178   40.675549           68   -73.999917    40.748428

# %%
# write function for getting average FHV and SFHV times
#### hint: function will essentially be the same as for FHV except for the change in the request parameters and returning 
def FHVtimes(df):
    
    # code here
    FHV_times = []
    SFHV_times = []
    
    for index, row in df.iterrows(): 
        
        FHV_parameters = {'pulocationid': row['LocationID'], 'dolocationid': row['LocationID2']  }
        SFHV_parameters = {'pulocationid': row['LocationID'], 'dolocationid': row['LocationID2'] , 'sr_flag':1 }
        
        url =  " https://data.cityofnewyork.us/resource/u6nh-b56h.json"
        r = requests.get(url = url, params=FHV_parameters)
        R = requests.get(url = url, params=SFHV_parameters)
        data1 = r.json()
        data2 = R.json()
        
        travelTime1 = []
        travelTime2 = []
        
        for obs in data1: 
            
            try:
                time = parser.parse(obs['dropoff_datetime']) - parser.parse(obs['pickup_datetime'])
                time = time.total_seconds()

                if (time < 6000 and time > 60 ):
                    travelTime1.append(time)
                   
            except: 
                pass
            
        for obs in data2: 
            
            try:
                time = parser.parse(obs['dropoff_datetime']) - parser.parse(obs['pickup_datetime'])
                time = time.total_seconds()

                if (time < 6000 and time > 60 ):
                    travelTime2.append(time)
                      
            except: 
                pass
        while np.nan in travelTime1:
            travelTime1.remove(np.nan)
        while np.nan in travelTime2:
            travelTime2.remove(np.nan)
        
        FHV_times.append(np.mean(travelTime1))
        SFHV_times.append(np.mean(travelTime2))

    return (FHV_times,SFHV_times)

# %%
## requests from API (call the above function)
a=FHVtimes(sample)
# Out:
# C:\Users\14367\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\14367\anaconda3\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
# create new columns in the above 'sample' dataframe named 'FHV time' and 'SFHV time' with above retrieved times
sample['FHV time'] = list(a[0])
sample['SFHV time'] = list(a[1])
sample.head()
# Out:
#      LocationID  lon_pickup  lat_pickup  LocationID2  lon_dropoff  \
# 109         110  -74.128342   40.545780          254   -73.858948
# 50           51  -73.828264   40.873973           92   -73.828859
# 165         166  -73.961764   40.809457          234   -73.990458
# 206         207  -73.899353   40.763986          248   -73.872289
# 194         195  -74.009178   40.675549           68   -73.999917
#
#      lat_dropoff     FHV time    SFHV time
# 109    40.882157          NaN          NaN
# 50     40.761102  1431.289157  1493.700000
# 165    40.740337  1890.944193  2217.561224
# 206    40.834165  1511.000000          NaN
# 194    40.748428  1640.843750  1828.200000

# %%
sample=sample.dropna(axis=0,how='any')
sample
# Out:
#      LocationID  lon_pickup  lat_pickup  LocationID2  lon_dropoff  \
# 50           51  -73.828264   40.873973           92   -73.828859
# 165         166  -73.961764   40.809457          234   -73.990458
# 194         195  -74.009178   40.675549           68   -73.999917
# 164         165  -73.956825   40.620924          258   -73.855767
# 144         145  -73.948891   40.745379           80   -73.936793
# 224         225  -73.931888   40.688168          111   -73.990235
# 34           35  -73.910258   40.664003          124   -73.844919
# 245         246  -74.004015   40.753309          197   -73.830924
# 221         222  -73.882413   40.647527          131   -73.776101
# 87           88  -74.011515   40.703358           35   -73.910258
# 162         163  -73.977569   40.764421           78   -73.885522
# 61           62  -73.948789   40.666540          141   -73.959635
# 58           59  -73.894986   40.838550           82   -73.877118
# 158         159  -73.912849   40.818260          263   -73.951010
# 31           32  -73.864901   40.864002          169   -73.905122
# 101         102  -73.875736   40.703546          165   -73.956825
# 25           26  -73.988661   40.630950          150   -73.943629
# 241         242  -73.850671   40.846783           81   -73.836643
# 180         181  -73.981414   40.670374          152   -73.953782
# 242         243  -73.932831   40.857108          192   -73.815229
# 106         107  -73.984052   40.736824          142   -73.981532
# 214         215  -73.790964   40.694428          177   -73.913632
# 35           36  -73.917711   40.700522           33   -73.995250
# 220         221  -74.073704   40.618769          133   -73.976199
# 23           24  -73.965480   40.801970          250   -73.848641
# 192         193  -73.941997   40.760314           62   -73.948789
# 247         248  -73.872289   40.834165          231   -74.007880
# 27           28  -73.808729   40.711596          100   -73.988787
# 151         152  -73.953782   40.817975           14   -74.029892
# 115         116  -73.948522   40.827013          122   -73.761137
#
#      lat_dropoff     FHV time    SFHV time
# 50     40.761102  1431.289157  1493.700000
# 165    40.740337  1890.944193  2217.561224
# 194    40.748428  1640.843750  1828.200000
# 164    40.688721  2505.500000  2552.625000
# 144    40.715370   868.151151  1101.231818
# 224    40.652137  1535.833333  2059.000000
# 34     40.658248  1262.839196  1479.818182
# 245    40.694542  3028.142857  2856.833333
# 221    40.720655  2319.176471  1905.000000
# 87     40.664003  2415.201550  2459.250000
# 162    40.844960  2227.893939  2637.000000
# 61     40.766948  2815.722222  2655.181818
# 58     40.739496  1628.428571  1791.333333
# 158    40.778766  1243.918033  1373.955224
# 31     40.849058  1050.680000  1323.537634
# 101    40.620924  2779.105263  2654.000000
# 25     40.580473  1810.206704  1952.137500
# 241    40.880935   921.833000  1137.325967
# 180    40.817975  2520.184211  2698.769231
# 242    40.743751  1802.533333  2151.333333
# 106    40.773633  1443.635000  1661.012821
# 214    40.676644  1852.072993  2142.875000
# 35     40.695798  1742.624852  2008.919463
# 220    40.640590  2027.454545  1940.000000
# 23     40.832102  1728.545455  1962.375000
# 192    40.666540  2261.320000  2377.250000
# 247    40.717773  2501.828571  2750.400000
# 27     40.753513  2320.947368  3306.000000
# 151    40.624835  2592.619048  3011.600000
# 115    40.710639  2858.600000  2362.500000

# %% [markdown]
# ### Task 3: Comparison of times for FHV and shared FHV

# %%
## check number of 'Nan' values (if any) retrieved from travel times

# %%
# remove the rows if any of the retrieved FHV or shared FHV times has 'Nan'

# %%
# make scatter plot comparing FHV times with shared FHV times for the 50 sample O-D pairs
# add a FHV=SFHV baseline to see if most of the points are above (FHV time>SFHV time) or below (FHV time<SFHV time)

# hint: use plt.plot(var1, var2, 'o') for scatter plots between two variables var1 and var2 of interest

# %%
# Sample dataframe (for demonstration purposes)
# In actual scenarios, this should be the dataframe with randomly chosen start-end pairs.

import matplotlib.pyplot as plt
sample = pd.DataFrame({
    'PULocationID': np.random.randint(1, 265, 50),
    'DOLocationID': np.random.randint(1, 265, 50)
})

# Simulated results from FHVtimes function (since we cannot actually call the API)
# Randomly generating travel times for demonstration.
sample['FHV time'] = np.random.randint(10, 60, 50)  # in minutes
sample['SFHV time'] = sample['FHV time'] + np.random.randint(-10, 10, 50)  # adding some variation

# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(sample['FHV time'], sample['SFHV time'], color='blue', alpha=0.6, label='Start-End Pairs')
plt.plot([10, 60], [10, 60], color='red', linestyle='--', label='FHV = SFHV Line')
plt.xlabel('FHV Time (minutes)')
plt.ylabel('Shared FHV Time (minutes)')
plt.legend()
plt.title('Comparison of FHV and Shared FHV Travel Times')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Extra credit task- Using one other API : geocoding
# Geocoding referes to converting textual addresses into lat-long. Useful in getting a precise location of a place

# %% [markdown]
# we'll use HereAPI again for geocoding. Same API key as before will work. The endpoint for geocoding API is https://geocode.search.hereapi.com/v1/geocode
# Many other companies also provide geocoding API services (eg. Google)
#
# To specify an address, we use the 'q' parameter in the endpoint. For example, if we want to get lat-long for '5 Rue Daunou, 75000 Paris, France', we'll use the following endpoint:
#
# https://geocode.search.hereapi.com/v1/geocode?q=5+Rue+Daunou%2C+75000+Paris%2C+France&apiKey={}
#
# Essentially, we write the addresses as a query with spaces being replaced by '+' and commas being repalced by '%2C'

# %%
## try out a geocode request for a random address. Remember to be precise in specifying the address to remove any ambiguity

# API key
key = " "

# API endpoint with query as your address
url = " "


#data = urllib.urlopen(url).read().decode('utf-8')
#data = json.loads(data)
#data

# %%
## get latitude and longitude from returned json request
